,[2.81769928e-04,2.26149242e-03,1.75766015e-08,9.97456729e-01]
,[4.53288220e-02,2.11905763e-02,6.98133590e-05,9.33410823e-01]
,[6.86096842e-04,1.23349773e-02,7.48577662e-08,9.86978889e-01]
,[1.73639436e-03,3.21076028e-02,4.15838741e-07,9.66155589e-01]
,[2.19888776e-03,5.22614010e-02,1.39162307e-06,9.45538342e-01]
,[8.55402264e-04,2.97916820e-03,9.58944124e-09,9.96165395e-01]
,[3.43303685e-03,4.59406227e-02,1.28404440e-06,9.50625002e-01]
,[7.47649791e-03,1.47905335e-01,1.82948279e-05,8.44599843e-01]
,[7.32835790e-04,1.91212585e-03,7.24844806e-09,9.97355103e-01]
,[3.44237164e-02,8.24076869e-03,1.11202207e-05,9.57324445e-01]]

# %%
import torch
# score2mri = [s[:11] for s in score2mri]
cin2score = torch.tensor(cin2score)
score2cli = torch.tensor(score2cli)
cin2mri = torch.tensor(cin2mri)
mri2cli = torch.tensor(mri2cli)
score2mri = torch.tensor(score2mri)
mri2score = torch.tensor(mri2score)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


tensor = cin2score


df = pd.DataFrame(tensor)
clin = ['Apoe','Age','Gender','Edu']
scores = ['NPITOTAL','COMP_EXEC_FUNC','MODHACH','MMSE','LOG_MEM_DEL','CBB','ADAS','CDR','COMP_MEM']

plt.figure(figsize=(10, 4))


sns.set()


ax = sns.heatmap(df, cmap='Reds', annot=True, cbar=True, xticklabels=clin, yticklabels=scores)

ax.set_xticklabels(ax.get_xmajorticklabels(), fontsize=10)
ax.set_yticklabels(ax.get_ymajorticklabels(), fontsize=10)


cbar = ax.collections[0].colorbar
cbar.set_label('Values', fontsize=12)


plt.xticks(rotation=45,size=18)
plt.yticks(rotation=0,size=18)


plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

matrix = mri2cli


matrix_transposed = matrix.T


plt.figure(figsize=(10, 6))
sns.heatmap(matrix_transposed, cmap='Purples',vmin=0, vmax=1,xticklabels=['Age','Apoe','Edu','Gender'],yticklabels=False) #['Age','Gender','Apoe','Edu']
for i in range(matrix_transposed.shape[0]):
    for j in range(matrix_transposed.shape[1]):
        if matrix_transposed[i, j] > 0.01:
            rect = Rectangle((j, i), 1, 1, fill=False, linestyle='dashed', edgecolor='grey')
            plt.gca().add_patch(rect)
# plt.xlabel('Clinical Features')
plt.ylabel('MRI/PET Modal',size=18)
# plt.title('Attention between Clinical Features and MRI')
plt.xticks(rotation=45,size=18)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

matrix = mri2score

matrix_transposed = matrix.T

plt.figure(figsize=(10, 6))
# viridis
sns.heatmap(matrix_transposed, cmap='Blues', vmin=0, vmax=1,xticklabels=['CDR','COMP_EXEC_FUNC','MODHACH','MMSE','LOG_MEM_DEL','CBB','ADAS','NPITOTAL','COMP_MEM'],yticklabels=False)

for i in range(matrix_transposed.shape[0]):
    for j in range(matrix_transposed.shape[1]):
        if matrix_transposed[i, j] > 0.1:
            rect = Rectangle((j, i), 1, 1, fill=False, linestyle='dashed', edgecolor='grey')
            plt.gca().add_patch(rect)
# plt.xlabel('Neurological Scales')
plt.ylabel('MRI/PET Modal',size=18)
# plt.title('Attention between Neurological Scales and MRI')
plt.xticks(rotation=45,size=18)
plt.show()
